# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('movies.csv', sep=',')
rating=pd.read_csv('rating.csv',sep=',')
tags = pd.read_csv('tags.csv', sep=',')
links=pd.read_csv('links.csv',sep=',')
marks=pd.read_csv('student trial1.csv',sep=',')
marks=pd.DataFrame(marks)
marks
# Out:
#     studentid  phy  chem  mat   remark
# 0           1  130   152  100     good
# 1           2  140   142  100  average
# 2           2  115   121  100     poor
# 3           3  125   110  100     good
# 4           4  154   113  100  average
# 5           5  121   124  100     poor
# 6           1  121   110  100     good
# 7           2  121    75  100  average
# 8           3  155    75  100     poor
# 9           4  154    75  100     good
# 10          5  142    75  100  average
# 11          6  142   100  100     poor
# 12          7  142   125  100  average
# 13          8  142   100  100     poor
# 14          8  142   100  100     good
# 15          7  142   100  100  average
# 16          6  142   100  100     poor
# 17          5  145   100  100     good
# 18          7  145   100  100  average

# %%
del movies.iloc[10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-44a39cd7683e> in <module>()
# ----> 1 del movies.iloc[10]
#
# AttributeError: __delitem__

# %%
movies=movies.drop(movies.index[[1,2,3,4]])

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
markstable=pd.read_excel('student trial.xls',[0])
print(markstable.keys)
#markstable=pd.DataFrame(markstable,index=markstable.studentid)

#marksheettable=pd.ExcelFile.parse('student trial.xls',[0])
markstable
# Out:
# <built-in method keys of collections.OrderedDict object at 0x098D3B70>
# OrderedDict([(0,     studentid  phy  chem  mat
#               0           1  130   152  100
#               1           2  140   142  100
#               2           2  115   121  100
#               3           3  125   110  100
#               4           4  154   113  100
#               5           5  121   124  100
#               6           1  121   110  100
#               7           2  121    75  100
#               8           3  155    75  100
#               9           4  154    75  100
#               10          5  142    75  100
#               11          6  142   100  100
#               12          7  142   125  100
#               13          8  142   100  100
#               14          8  142   100  100
#               15          7  142   100  100
#               16          6  142   100  100
#               17          5  145   100  100
#               18          7  145   100  100)])

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
movies['newcolumn']=tags['userId']
movies.loc[10]
# Out:
# movieId                     15
# title        russian President
# genres                  comedy
# newcolumn                   65
# Name: 10, dtype: object

# %%
movies.loc[10]=[15,"russian President","comedy",85]
movies.loc[10]
# Out:
# movieId                     15
# title        russian President
# genres                  comedy
# newcolumn                   85
# Name: 10, dtype: object

# %%
movies.loc[5]
# Out:
# movieId                          6
# title                  Heat (1995)
# genres       Action|Crime|Thriller
# newcolumn                       65
# Name: 5, dtype: object

# %%
movies.drop(movies.index[5])
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          15                                  russian President
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# 13          14                                       Nixon (1995)
# ...

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          15                                  russian President
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
movies=movies.drop(movies.index[5])
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 55          56                     Kids of the Round Table (1995)
# 56          57                       Home for the Holidays (1995)
# 57          58                  Postman, The (Postino, Il) (1994)
# 58          59       Confessional, The (Confessionnal, Le) (1995)
# 59          60                 Indian in the Cupboard, The (1995)
# 60          61                              Eye for an Eye (1996)
# 61          62                          Mr. Holland's Opus (1995)
# 62          63  Don't Be a Menace to South Central While Drink...
# ...

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres', 'newcolumn'], dtype='object')

# %%
del movies['newcolumn']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'newcolumn'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-3eab97313530> in <module>()
# ----> 1 del movies['newcolumn']
#
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
marks.groupby('studentid')

# %%
marks
# Out:
#     studentid  phy  chem  mat   remark
# 0           1  130   152  100     good
# 1           2  140   142  100  average
# 2           2  115   121  100     poor
# 3           3  125   110  100     good
# 4           4  154   113  100  average
# 5           5  121   124  100     poor
# 6           1  121   110  100     good
# 7           2  121    75  100  average
# 8           3  155    75  100     poor
# 9           4  154    75  100     good
# 10          5  142    75  100  average
# 11          6  142   100  100     poor
# 12          7  142   125  100  average
# 13          8  142   100  100     poor
# 14          8  142   100  100     good
# 15          7  142   100  100  average
# 16          6  142   100  100     poor
# 17          5  145   100  100     good
# 18          7  145   100  100  average

# %%
marks1=marks.groupby("studentid")
print(type(marks1))
ma=marks1.describe()
ma
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
#            chem                                                              \
#           count        mean        std    min     25%    50%     75%    max
# studentid
# 1           2.0  131.000000  29.698485  110.0  120.50  131.0  141.50  152.0
# 2           3.0  112.666667  34.268547   75.0   98.00  121.0  131.50  142.0
# 3           2.0   92.500000  24.748737   75.0   83.75   92.5  101.25  110.0
# 4           2.0   94.000000  26.870058   75.0   84.50   94.0  103.50  113.0
# 5           3.0   99.666667  24.501701   75.0   87.50  100.0  112.00  124.0
# 6           2.0  100.000000   0.000000  100.0  100.00  100.0  100.00  100.0
# 7           3.0  108.333333  14.433757  100.0  100.00  100.0  112.50  125.0
# 8           2.0  100.000000   0.000000  100.0  100.00  100.0  100.00  100.0
#
#             mat         ...                   phy                         \
#           count   mean  ...      75%    max count        mean        std
# ...

# %%
df=marks.groupby('studentid')
df

# %%
movies.count()
# Out:
# movieId    27278
# title      27278
# genres     27278
# dtype: int64

# %%
movies[27270:27278]
# Out:
#        movieId                                              title  \
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 27270  Adventure|Animation|Children|Comedy|Fantasy
# 27271                                       Comedy
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# ...

# %%
movies[-8:]
# Out:
#        movieId                                              title  \
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 27270  Adventure|Animation|Children|Comedy|Fantasy
# 27271                                       Comedy
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# ...

# %%
#remove rows with certain value
movies=movies.replace('(no genres listed)',np.nan).dropna()

# %%
#count the value for each group of values
movie_counts=movies['genres'].value_counts()
movies.contains("Drama")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-259-4459d303fcf5> in <module>()
#       1 #count the value for each group of values
#       2 movie_counts=movies['genres'].value_counts()
# ----> 3 movies.contains("Drama")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'contains'

# %%
movies[-2:]
# Out:
#        movieId               title                    genres
# 27275   131258  The Pirates (2014)                 Adventure
# 27277   131262    Innocence (2014)  Adventure|Fantasy|Horror

# %%
# %matplotlib inline
movie_counts[:10].plot(kind='pie',figsize=(10,10))

# %%
is_action_only=movies['genres'].str.contains('Action')
#is_Romance_only=movies['genres']=='Romance'
movies[is_action_only]
# Out:
#        movieId                                              title  \
# 5            6                                        Heat (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 14          15                            Cutthroat Island (1995)
# 19          20                                 Money Train (1995)
# 22          23                                   Assassins (1995)
# 41          42                             Dead Presidents (1995)
# 43          44                               Mortal Kombat (1995)
# 50          51                              Guardian Angel (1994)
# 65          66          Lawnmower Man 2: Beyond Cyberspace (1996)
# 69          70                         From Dusk Till Dawn (1996)
# 70          71                                   Fair Game (1995)
# 75          76                                   Screamers (1995)
# ...

# %%
#to find no. of ratings received for a movie
average_rating=rating[['movieId','rating']].groupby('movieId').count()
average_rating
# Out:
#          rating
# movieId
# 2          1155
# 3           685
# 4           138

# %%
#to find the average rating for a movie
average_rating=rating[['movieId','rating']].groupby('movieId').mean()
average_rating
# Out:
#            rating
# movieId
# 2        3.268398
# 3        3.186861
# 4        3.000000
