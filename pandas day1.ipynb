# %%
import pandas as pd
from decimal import Decimal

# %%
movies = pd.read_csv(r'''C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\movies.csv''', sep=',')
print(type(movies))
movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970
tags = pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\tags.csv', sep=',')
ratings=pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\ratings.csv',sep=',')
links=pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\links.csv',sep=',')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(tags.iloc[0])
type(tags.iloc[0])
# Out:
# userId                          15
# movieId                        339
# tag        sandra 'boring' bullock
# Name: 0, dtype: object
# pandas.core.series.Series

# %%
row_0=tags.iloc[0]

# %%
row_0
# Out:
# userId                          15
# movieId                        339
# tag        sandra 'boring' bullock
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0.name
# Out:
# 0

# %%
row_0.name='first_row'

# %%
row_0
# Out:
# userId                          15
# movieId                        339
# tag        sandra 'boring' bullock
# Name: first_row, dtype: object

# %%
print(row_0,tags.iloc[1].rename('abs'),sep='\n\n')
# Out:
# userId                          15
# movieId                        339
# tag        sandra 'boring' bullock
# Name: first_row, dtype: object
#
# userId          15
# movieId       1955
# tag        dentist
# Name: abs, dtype: object

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
#iloc example
tags.columns.name=('Serial number')
print(tags.columns)
print(tags.iloc[[1,5,10,1000]])
del tags.columns.name
print("\n")
print("with print function\n")
print(tags.iloc[[1,5,10,1000]])
print("\nwithout print function\n")
tags.iloc[[1,5,10,1000]]
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object', name='Serial number')
# Serial number  userId  movieId        tag   timestamp
# 1                  15     1955    dentist  1193435061
# 5                  15    35957      short  1141391873
# 10                 15   100365     uganda  1425876220
# 1000              547    44199  toplist06  1197165844
#
#
# with print function
#
#       userId  movieId        tag   timestamp
# 1         15     1955    dentist  1193435061
# 5         15    35957      short  1141391873
# 10        15   100365     uganda  1425876220
# 1000     547    44199  toplist06  1197165844
#
# without print function
#       userId  movieId        tag   timestamp
# 1         15     1955    dentist  1193435061
# 5         15    35957      short  1141391873
# 10        15   100365     uganda  1425876220
# 1000     547    44199  toplist06  1197165844

# %%
# !type C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\links.csv
# Out:
# movieId,imdbId,tmdbId
# 1,0114709,862
# 2,0113497,8844
# 3,0113228,15602
# 4,0114885,31357
# 5,0113041,11862
# 6,0113277,949
# 7,0114319,11860
# 8,0112302,45325
# 9,0114576,9091
# 10,0113189,710
# 11,0112346,9087
# 12,0112896,12110
# 13,0112453,21032
# 14,0113987,10858
# 15,0112760,1408
# 16,0112641,524
# 17,0114388,4584
# 18,0113101,5
# 19,0112281,9273
# 20,0113845,11517
# 21,0113161,8012
# 22,0112722,1710
# 23,0112401,9691
# 24,0114168,12665
# 25,0113627,451
# 26,0114057,16420
# 27,0114011,9263
# 28,0114117,17015
# 29,0112682,902
# 30,0115012,37557
# 31,0112792,9909
# 32,0114746,63
# 34,0112431,9598
# 35,0112637,47018
# 36,0112818,687
# 37,0112286,139405
# 38,0113442,33689
# 39,0112697,9603
# 40,0112749,34615
# 41,0114279,31174
# 42,0112819,11443
# 43,0114272,35196
# 44,0113855,9312
# 45,0114681,577
# 46,0113347,11861
# 47,0114369,807
# 48,0114148,10530
# 49,0114916,8391
# 50,0114814,629
# 52,0113819,11448
# 53,0110299,49133
# 54,0112499,26441
# 55,0113158,97406
# 57,0113321,9089
# ...

# %% [raw]
# #dataFrames
# movies = pd.read_csv(r'''C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\movies.csv''', sep=',')
# tags = pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\tags.csv', sep=',')
# ratings=pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\ratings.csv',sep=',')
# links=pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\links.csv',sep=',')

# %%
print("## movies")
print(type(movies))
print(movies.head())
print("## tags")
print(type(tags))
print(tags.head())
print("## ratings")
print(type(ratings))
print(ratings.head())
print("## links")
print(type(links))
print(links.head())
# Out:
# ## movies
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# ## tags
# <class 'pandas.core.frame.DataFrame'>
#    userId  movieId                      tag   timestamp
# 0      15      339  sandra 'boring' bullock  1138537770
# 1      15     1955                  dentist  1193435061
# 2      15     7478                 Cambodia  1170560997
# 3      15    32892                  Russian  1170626366
# ...

# %%
ratings = pd.read_csv(r'C:\Users\668376\Desktop\ml-latest-small\ml-latest-small\ratings.csv', sep=',', parse_dates=['timestamp'])
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# 5            1     1263     2.0  1260759151
# 6            1     1287     2.0  1260759187
# 7            1     1293     2.0  1260759148
# 8            1     1339     3.5  1260759125
# 9            1     1343     2.0  1260759131
# 10           1     1371     2.5  1260759135
# 11           1     1405     1.0  1260759203
# 12           1     1953     4.0  1260759191
# 13           1     2105     4.0  1260759139
# 14           1     2150     3.0  1260759194
# 15           1     2193     2.0  1260759198
# 16           1     2294     2.0  1260759108
# 17           1     2455     2.5  1260759113
# 18           1     2968     1.0  1260759200
# 19           1     3671     3.0  1260759117
# ...

# %%
#accessing a list of elements with iloc and loc and ix
ratings.columns
rows=['1','1','2','6','1000']
rows1=[1,2,5,7,1000]
cols=['userId','rating']
print(ratings.iloc[rows][cols])
print("#loc\n\n")
print(ratings.loc[rows1][cols])
print("##ix warining it is depreciated and advised not to use")
print("\n",ratings.ix[rows1][cols])
print("##with row element as strings")
print("\n",ratings.ix[rows][cols])
# Out:
#       userId  rating
# 1          1     3.0
# 1          1     3.0
# 2          1     3.0
# 6          1     2.0
# 1000      15     2.0
# #loc
#
#
#       userId  rating
# 1          1     3.0
# 2          1     3.0
# 5          1     2.0
# 7          1     2.0
# 1000      15     2.0
# ##ix warining it is depreciated and advised not to use
#
#        userId  rating
# 1          1     3.0
# 2          1     3.0
# 5          1     2.0
# 7          1     2.0
# 1000      15     2.0
# ##with row element as strings
#
#        userId  rating
# 1        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 6        NaN     NaN
# 1000     NaN     NaN

# %%
print("\n for single rating column")
ratings.rating.describe()
# Out:
#  for single rating column
# count    100004.000000
# mean          3.543608
# std           1.058064
# min           0.500000
# 25%           3.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
print("\n for all columns")
type(ratings.describe())
# Out:
#  for all columns
# pandas.core.frame.DataFrame

# %%
print(int(ratings.mean()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-232-e3cb1100ff13> in <module>()
# ----> 1 print(int(ratings.mean()))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
pd.to_numeric(ratings.mean(),errors='raise',downcast=int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-b781a55432e7> in <module>()
# ----> 1 pd.to_numeric(ratings.mean(),errors='raise',downcast=int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#      87     """
#      88     if downcast not in (None, 'integer', 'signed', 'unsigned', 'float'):
# ---> 89         raise ValueError('invalid downcasting method provided')
#      90
#      91     is_series = False
#
# ValueError: invalid downcasting method provided

# %%
ratings.mean().astype(int,errors='ignore')

# %%
pd.corr(ratings)

# %%
print("hii")
